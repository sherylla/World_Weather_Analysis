# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 717

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=88e98b69e0edd5cbed56213489c1aac4

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        #city_wind = city_weather.get("wind",{}).get("speed",0)
        city_country = city_weather["sys"]["country"]
        city_weather_info = city_weather["weather"]
        weather_description = city_weather_info[0]["description"]
        #city_rain = city_weather["rain"]["3h"]
        city_rain = city_weather.get("rain",{}).get("3h",0.00)
        city_snow = city_weather.get("snow",{}).get("3h",0.00)
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description" : weather_description,
                          "Rain Inches (last 3 hours)" : city_rain,
                          "Snow Inches (last 3 hours)" : city_snow,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | cabo san lucas
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | saint anthony
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | provideniya
# Processing Record 9 of Set 1 | castro
# Processing Record 10 of Set 1 | ambilobe
# Processing Record 11 of Set 1 | chapais
# Processing Record 12 of Set 1 | putyatino
# Processing Record 13 of Set 1 | maniitsoq
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | peniche
# Processing Record 17 of Set 1 | birao
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | asau
# Processing Record 21 of Set 1 | tahta
# Processing Record 22 of Set 1 | clarence town
# Processing Record 23 of Set 1 | ngunguru
# Processing Record 24 of Set 1 | henties bay
# Processing Record 25 of Set 1 | bathsheba
# Processing Record 26 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 1 | kresek
# Processing Record 28 of Set 1 | forbes
# Processing Record 29 of Set 1 | shimoda
# Processing Record 30 of Set 1 | namibe
# Processing Record 31 of Set 1 | esil
# Processing Record 32 of Set 1 | xining
# Processing Record 33 of Set 1 | sinnamary
# Processing Record 34 of Set 1 | akhtubinsk
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | berdigestyakh
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | narsaq
# Processing Record 39 of Set 1 | ponta delgada
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | dipkarpaz
# City not found. Skipping...
# Processing Record 42 of Set 1 | manaure
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | mehamn
# Processing Record 46 of Set 1 | la ronge
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | jaciara
# Processing Record 49 of Set 1 | vanimo
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | hinton
# Processing Record 4 of Set 2 | esperance
# Processing Record 5 of Set 2 | biak
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 2 | bubaque
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | panguna
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 2 | luderitz
# Processing Record 13 of Set 2 | codrington
# Processing Record 14 of Set 2 | staryy biser
# City not found. Skipping...
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | gallup
# Processing Record 18 of Set 2 | east london
# Processing Record 19 of Set 2 | constitucion
# Processing Record 20 of Set 2 | opuwo
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | xunchang
# Processing Record 23 of Set 2 | ucluelet
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | walvis bay
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | dikson
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | kongolo
# Processing Record 31 of Set 2 | mitsamiouli
# Processing Record 32 of Set 2 | rovaniemi
# Processing Record 33 of Set 2 | ipixuna
# Processing Record 34 of Set 2 | pampa
# Processing Record 35 of Set 2 | maldonado
# Processing Record 36 of Set 2 | lubben
# Processing Record 37 of Set 2 | kavaratti
# Processing Record 38 of Set 2 | taltal
# Processing Record 39 of Set 2 | urucui
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | lahij
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | cape canaveral
# Processing Record 44 of Set 2 | chimbote
# Processing Record 45 of Set 2 | kaitangata
# Processing Record 46 of Set 2 | maragogi
# Processing Record 47 of Set 2 | atherton
# Processing Record 48 of Set 2 | takaka
# Processing Record 49 of Set 2 | hasaki
# Processing Record 50 of Set 2 | tuatapere
# Processing Record 1 of Set 3 | casper
# Processing Record 2 of Set 3 | tuktoyaktuk
# Processing Record 3 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 3 | quang ngai
# Processing Record 5 of Set 3 | airai
# Processing Record 6 of Set 3 | vesoul
# Processing Record 7 of Set 3 | lorengau
# Processing Record 8 of Set 3 | iqaluit
# Processing Record 9 of Set 3 | puerto ayora
# Processing Record 10 of Set 3 | maniwaki
# Processing Record 11 of Set 3 | kyzyl-suu
# Processing Record 12 of Set 3 | salalah
# Processing Record 13 of Set 3 | knysna
# Processing Record 14 of Set 3 | moron
# Processing Record 15 of Set 3 | husavik
# Processing Record 16 of Set 3 | port elizabeth
# Processing Record 17 of Set 3 | vermillion
# Processing Record 18 of Set 3 | oblivskaya
# Processing Record 19 of Set 3 | torbay
# Processing Record 20 of Set 3 | nome
# Processing Record 21 of Set 3 | honiara
# Processing Record 22 of Set 3 | pangnirtung
# Processing Record 23 of Set 3 | college
# Processing Record 24 of Set 3 | yellowknife
# Processing Record 25 of Set 3 | butaritari
# Processing Record 26 of Set 3 | bouna
# Processing Record 27 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 3 | yingkou
# Processing Record 29 of Set 3 | te anau
# Processing Record 30 of Set 3 | senneterre
# Processing Record 31 of Set 3 | kyren
# Processing Record 32 of Set 3 | hobart
# Processing Record 33 of Set 3 | port macquarie
# Processing Record 34 of Set 3 | emerald
# Processing Record 35 of Set 3 | porbandar
# Processing Record 36 of Set 3 | sirjan
# Processing Record 37 of Set 3 | vlakhokerasea
# City not found. Skipping...
# Processing Record 38 of Set 3 | acuna
# City not found. Skipping...
# Processing Record 39 of Set 3 | antsohihy
# Processing Record 40 of Set 3 | puerto del rosario
# Processing Record 41 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 3 | aykhal
# Processing Record 43 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 3 | geraldton
# Processing Record 45 of Set 3 | hami
# Processing Record 46 of Set 3 | bluff
# Processing Record 47 of Set 3 | albany
# Processing Record 48 of Set 3 | port moresby
# Processing Record 49 of Set 3 | jalu
# Processing Record 50 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 4 | charters towers
# Processing Record 2 of Set 4 | porto walter
# Processing Record 3 of Set 4 | nanortalik
# Processing Record 4 of Set 4 | talnakh
# Processing Record 5 of Set 4 | sars
# Processing Record 6 of Set 4 | isangel
# Processing Record 7 of Set 4 | vilhena
# Processing Record 8 of Set 4 | faanui
# Processing Record 9 of Set 4 | chuy
# Processing Record 10 of Set 4 | khatanga
# Processing Record 11 of Set 4 | saldanha
# Processing Record 12 of Set 4 | yulara
# Processing Record 13 of Set 4 | mount gambier
# Processing Record 14 of Set 4 | touros
# Processing Record 15 of Set 4 | olafsvik
# Processing Record 16 of Set 4 | ancud
# Processing Record 17 of Set 4 | la libertad
# Processing Record 18 of Set 4 | laje
# Processing Record 19 of Set 4 | pacific grove
# Processing Record 20 of Set 4 | xuanzhou
# Processing Record 21 of Set 4 | cockburn town
# Processing Record 22 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 4 | lazaro cardenas
# Processing Record 24 of Set 4 | margate
# Processing Record 25 of Set 4 | the valley
# Processing Record 26 of Set 4 | leningradskiy
# Processing Record 27 of Set 4 | lagoa
# Processing Record 28 of Set 4 | progreso
# Processing Record 29 of Set 4 | feijo
# Processing Record 30 of Set 4 | mabaruma
# Processing Record 31 of Set 4 | berezovyy
# Processing Record 32 of Set 4 | storforshei
# Processing Record 33 of Set 4 | vao
# Processing Record 34 of Set 4 | bandarbeyla
# Processing Record 35 of Set 4 | karpathos
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | tessalit
# Processing Record 38 of Set 4 | olinda
# Processing Record 39 of Set 4 | kodiak
# Processing Record 40 of Set 4 | nuuk
# Processing Record 41 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 42 of Set 4 | pisco
# Processing Record 43 of Set 4 | mariental
# Processing Record 44 of Set 4 | bambous virieux
# Processing Record 45 of Set 4 | bereda
# Processing Record 46 of Set 4 | tshikapa
# Processing Record 47 of Set 4 | zhezkazgan
# Processing Record 48 of Set 4 | vila franca do campo
# Processing Record 49 of Set 4 | mount hagen
# Processing Record 50 of Set 4 | guerrero negro
# Processing Record 1 of Set 5 | mengyin
# Processing Record 2 of Set 5 | lhokseumawe
# Processing Record 3 of Set 5 | usinsk
# Processing Record 4 of Set 5 | aklavik
# Processing Record 5 of Set 5 | tahoua
# Processing Record 6 of Set 5 | sakakah
# Processing Record 7 of Set 5 | taywarah
# Processing Record 8 of Set 5 | ponta do sol
# Processing Record 9 of Set 5 | vila velha
# Processing Record 10 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 5 | lavrentiya
# Processing Record 12 of Set 5 | dunedin
# Processing Record 13 of Set 5 | nhulunbuy
# Processing Record 14 of Set 5 | richards bay
# Processing Record 15 of Set 5 | minsk
# Processing Record 16 of Set 5 | grootfontein
# Processing Record 17 of Set 5 | goalpara
# Processing Record 18 of Set 5 | cherskiy
# Processing Record 19 of Set 5 | sampit
# Processing Record 20 of Set 5 | fort nelson
# Processing Record 21 of Set 5 | jaisalmer
# Processing Record 22 of Set 5 | karasuk
# Processing Record 23 of Set 5 | brae
# Processing Record 24 of Set 5 | quatre cocos
# Processing Record 25 of Set 5 | ingersoll
# Processing Record 26 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 5 | hambantota
# Processing Record 28 of Set 5 | yueyang
# Processing Record 29 of Set 5 | clyde river
# Processing Record 30 of Set 5 | waipawa
# Processing Record 31 of Set 5 | angoche
# Processing Record 32 of Set 5 | buala
# Processing Record 33 of Set 5 | campbell river
# Processing Record 34 of Set 5 | kodino
# Processing Record 35 of Set 5 | okhotsk
# Processing Record 36 of Set 5 | raudeberg
# Processing Record 37 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 5 | aberdeen
# Processing Record 39 of Set 5 | avarua
# Processing Record 40 of Set 5 | alipur
# Processing Record 41 of Set 5 | pitimbu
# Processing Record 42 of Set 5 | bac lieu
# Processing Record 43 of Set 5 | ahipara
# Processing Record 44 of Set 5 | las choapas
# Processing Record 45 of Set 5 | kombissiri
# Processing Record 46 of Set 5 | aitape
# Processing Record 47 of Set 5 | pontianak
# Processing Record 48 of Set 5 | seoul
# Processing Record 49 of Set 5 | muros
# Processing Record 50 of Set 5 | blessington
# Processing Record 1 of Set 6 | san patricio
# Processing Record 2 of Set 6 | lar gerd
# City not found. Skipping...
# Processing Record 3 of Set 6 | mandalgovi
# Processing Record 4 of Set 6 | souillac
# Processing Record 5 of Set 6 | tiksi
# Processing Record 6 of Set 6 | carnarvon
# Processing Record 7 of Set 6 | sao filipe
# Processing Record 8 of Set 6 | olovyannaya
# Processing Record 9 of Set 6 | nishihara
# Processing Record 10 of Set 6 | campeche
# Processing Record 11 of Set 6 | lasa
# Processing Record 12 of Set 6 | marsabit
# Processing Record 13 of Set 6 | egvekinot
# Processing Record 14 of Set 6 | bilokurakyne
# Processing Record 15 of Set 6 | taveta
# Processing Record 16 of Set 6 | dagana
# Processing Record 17 of Set 6 | san joaquin
# Processing Record 18 of Set 6 | akyab
# Processing Record 19 of Set 6 | saint george
# Processing Record 20 of Set 6 | kota kinabalu
# Processing Record 21 of Set 6 | muisne
# Processing Record 22 of Set 6 | kudat
# Processing Record 23 of Set 6 | saint-augustin
# Processing Record 24 of Set 6 | bengkulu
# Processing Record 25 of Set 6 | severo-kurilsk
# Processing Record 26 of Set 6 | kidal
# Processing Record 27 of Set 6 | batemans bay
# Processing Record 28 of Set 6 | ust-tsilma
# Processing Record 29 of Set 6 | zhumadian
# Processing Record 30 of Set 6 | wenling
# Processing Record 31 of Set 6 | buin
# Processing Record 32 of Set 6 | merauke
# Processing Record 33 of Set 6 | umm lajj
# Processing Record 34 of Set 6 | kupang
# Processing Record 35 of Set 6 | burica
# City not found. Skipping...
# Processing Record 36 of Set 6 | georgetown
# Processing Record 37 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 6 | nanakuli
# Processing Record 39 of Set 6 | villa carlos paz
# Processing Record 40 of Set 6 | banjar
# Processing Record 41 of Set 6 | ankang
# Processing Record 42 of Set 6 | bilma
# Processing Record 43 of Set 6 | tsiroanomandidy
# Processing Record 44 of Set 6 | kurilsk
# Processing Record 45 of Set 6 | victor harbor
# Processing Record 46 of Set 6 | plettenberg bay
# Processing Record 47 of Set 6 | qaanaaq
# Processing Record 48 of Set 6 | inuvik
# Processing Record 49 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 6 | sao miguel do araguaia
# Processing Record 1 of Set 7 | hamilton
# Processing Record 2 of Set 7 | marondera
# Processing Record 3 of Set 7 | roald
# Processing Record 4 of Set 7 | abu dhabi
# Processing Record 5 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 7 | ferrol
# Processing Record 7 of Set 7 | yumen
# Processing Record 8 of Set 7 | fukue
# Processing Record 9 of Set 7 | golkoy
# Processing Record 10 of Set 7 | mooresville
# Processing Record 11 of Set 7 | caramay
# Processing Record 12 of Set 7 | antofagasta
# Processing Record 13 of Set 7 | port lincoln
# Processing Record 14 of Set 7 | nouadhibou
# Processing Record 15 of Set 7 | melton
# Processing Record 16 of Set 7 | suileng
# Processing Record 17 of Set 7 | calbuco
# Processing Record 18 of Set 7 | cidreira
# Processing Record 19 of Set 7 | sainte-suzanne
# Processing Record 20 of Set 7 | half moon bay
# Processing Record 21 of Set 7 | tomatlan
# Processing Record 22 of Set 7 | bundaberg
# Processing Record 23 of Set 7 | beringovskiy
# Processing Record 24 of Set 7 | otjiwarongo
# Processing Record 25 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 7 | awbari
# Processing Record 27 of Set 7 | sonoita
# Processing Record 28 of Set 7 | magistralnyy
# Processing Record 29 of Set 7 | domoni
# Processing Record 30 of Set 7 | ilulissat
# Processing Record 31 of Set 7 | norman wells
# Processing Record 32 of Set 7 | providencia
# Processing Record 33 of Set 7 | cremona
# Processing Record 34 of Set 7 | ostrovnoy
# Processing Record 35 of Set 7 | san quintin
# Processing Record 36 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 7 | neiafu
# Processing Record 38 of Set 7 | abha
# Processing Record 39 of Set 7 | garden city
# Processing Record 40 of Set 7 | whitianga
# Processing Record 41 of Set 7 | yarke pole
# Processing Record 42 of Set 7 | mossendjo
# Processing Record 43 of Set 7 | guderup
# Processing Record 44 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 45 of Set 7 | palimbang
# Processing Record 46 of Set 7 | port hedland
# Processing Record 47 of Set 7 | longyearbyen
# Processing Record 48 of Set 7 | sjenica
# Processing Record 49 of Set 7 | alihe
# Processing Record 50 of Set 7 | palmer
# Processing Record 1 of Set 8 | naze
# Processing Record 2 of Set 8 | mankera
# Processing Record 3 of Set 8 | tateyama
# Processing Record 4 of Set 8 | mahina
# Processing Record 5 of Set 8 | dodoma
# Processing Record 6 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 8 | matara
# Processing Record 8 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 8 | klaksvik
# Processing Record 10 of Set 8 | batsfjord
# Processing Record 11 of Set 8 | isla del bosque
# Processing Record 12 of Set 8 | luanda
# Processing Record 13 of Set 8 | dingle
# Processing Record 14 of Set 8 | saint-philippe
# Processing Record 15 of Set 8 | esna
# Processing Record 16 of Set 8 | nabire
# Processing Record 17 of Set 8 | fayaoue
# Processing Record 18 of Set 8 | imeni babushkina
# Processing Record 19 of Set 8 | macapa
# Processing Record 20 of Set 8 | mount isa
# Processing Record 21 of Set 8 | ciudad bolivar
# Processing Record 22 of Set 8 | santiago de chuco
# Processing Record 23 of Set 8 | sioux lookout
# Processing Record 24 of Set 8 | ojinaga
# Processing Record 25 of Set 8 | mahebourg
# Processing Record 26 of Set 8 | yialos
# City not found. Skipping...
# Processing Record 27 of Set 8 | huilong
# Processing Record 28 of Set 8 | hithadhoo
# Processing Record 29 of Set 8 | marabba
# Processing Record 30 of Set 8 | korla
# Processing Record 31 of Set 8 | gushikawa
# Processing Record 32 of Set 8 | voineasa
# Processing Record 33 of Set 8 | san jose
# Processing Record 34 of Set 8 | piacabucu
# Processing Record 35 of Set 8 | agirish
# Processing Record 36 of Set 8 | wattegama
# Processing Record 37 of Set 8 | shatrovo
# Processing Record 38 of Set 8 | tiarei
# Processing Record 39 of Set 8 | kihei
# Processing Record 40 of Set 8 | lazarev
# Processing Record 41 of Set 8 | gizo
# Processing Record 42 of Set 8 | inta
# Processing Record 43 of Set 8 | miguel calmon
# Processing Record 44 of Set 8 | meulaboh
# Processing Record 45 of Set 8 | plymouth
# Processing Record 46 of Set 8 | praia da vitoria
# Processing Record 47 of Set 8 | umtata
# Processing Record 48 of Set 8 | inverness
# Processing Record 49 of Set 8 | zalantun
# Processing Record 50 of Set 8 | freeport
# Processing Record 1 of Set 9 | buchanan
# Processing Record 2 of Set 9 | xam nua
# Processing Record 3 of Set 9 | kysyl-syr
# Processing Record 4 of Set 9 | pimenta bueno
# Processing Record 5 of Set 9 | haines junction
# Processing Record 6 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 7 of Set 9 | banda aceh
# Processing Record 8 of Set 9 | sacramento
# Processing Record 9 of Set 9 | fortuna
# Processing Record 10 of Set 9 | verkhnyaya inta
# Processing Record 11 of Set 9 | hovd
# Processing Record 12 of Set 9 | hammerfest
# Processing Record 13 of Set 9 | dudinka
# Processing Record 14 of Set 9 | osmena
# Processing Record 15 of Set 9 | stara synyava
# Processing Record 16 of Set 9 | upernavik
# Processing Record 17 of Set 9 | vostok
# Processing Record 18 of Set 9 | zuwarah
# Processing Record 19 of Set 9 | las palmas
# Processing Record 20 of Set 9 | simao
# Processing Record 21 of Set 9 | soe
# Processing Record 22 of Set 9 | mahibadhoo
# Processing Record 23 of Set 9 | aksum
# Processing Record 24 of Set 9 | itapirapua
# Processing Record 25 of Set 9 | san ramon de la nueva oran
# Processing Record 26 of Set 9 | northam
# Processing Record 27 of Set 9 | drumnadrochit
# Processing Record 28 of Set 9 | kholtoson
# Processing Record 29 of Set 9 | balikpapan
# Processing Record 30 of Set 9 | ajdabiya
# Processing Record 31 of Set 9 | tautira
# Processing Record 32 of Set 9 | comodoro rivadavia
# Processing Record 33 of Set 9 | maun
# Processing Record 34 of Set 9 | atambua
# Processing Record 35 of Set 9 | palana
# Processing Record 36 of Set 9 | mecca
# Processing Record 37 of Set 9 | sobolevo
# Processing Record 38 of Set 9 | ola
# Processing Record 39 of Set 9 | waverley
# Processing Record 40 of Set 9 | leshukonskoye
# Processing Record 41 of Set 9 | baykit
# Processing Record 42 of Set 9 | chake chake
# Processing Record 43 of Set 9 | natal
# Processing Record 44 of Set 9 | sitka
# Processing Record 45 of Set 9 | kununurra
# Processing Record 46 of Set 9 | boyuibe
# Processing Record 47 of Set 9 | ginir
# Processing Record 48 of Set 9 | oron
# Processing Record 49 of Set 9 | jumla
# Processing Record 50 of Set 9 | mnogovershinnyy
# Processing Record 1 of Set 10 | strezhevoy
# Processing Record 2 of Set 10 | avera
# Processing Record 3 of Set 10 | port hardy
# Processing Record 4 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 10 | beloha
# Processing Record 6 of Set 10 | kahului
# Processing Record 7 of Set 10 | general roca
# Processing Record 8 of Set 10 | coos bay
# Processing Record 9 of Set 10 | manjeri
# Processing Record 10 of Set 10 | sergeyevka
# Processing Record 11 of Set 10 | prescott
# Processing Record 12 of Set 10 | komsomolskiy
# Processing Record 13 of Set 10 | buta
# Processing Record 14 of Set 10 | weligama
# Processing Record 15 of Set 10 | barabinsk
# Processing Record 16 of Set 10 | sao jose da coroa grande
# Processing Record 17 of Set 10 | hervey bay
# Processing Record 18 of Set 10 | svetlyy
# Processing Record 19 of Set 10 | aksarka
# Processing Record 20 of Set 10 | bagdarin
# Processing Record 21 of Set 10 | svetlogorsk
# Processing Record 22 of Set 10 | hoquiam
# Processing Record 23 of Set 10 | mayo
# Processing Record 24 of Set 10 | nizwa
# Processing Record 25 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 26 of Set 10 | la rioja
# Processing Record 27 of Set 10 | mackay
# Processing Record 28 of Set 10 | kloulklubed
# Processing Record 29 of Set 10 | ylojarvi
# Processing Record 30 of Set 10 | hit
# Processing Record 31 of Set 10 | hurghada
# Processing Record 32 of Set 10 | ilinskoye-khovanskoye
# Processing Record 33 of Set 10 | berlevag
# Processing Record 34 of Set 10 | dabakala
# Processing Record 35 of Set 10 | menomonie
# Processing Record 36 of Set 10 | karratha
# Processing Record 37 of Set 10 | los llanos de aridane
# Processing Record 38 of Set 10 | araouane
# Processing Record 39 of Set 10 | kurchum
# Processing Record 40 of Set 10 | estelle
# Processing Record 41 of Set 10 | batagay
# Processing Record 42 of Set 10 | touho
# Processing Record 43 of Set 10 | seymchan
# Processing Record 44 of Set 10 | tabou
# Processing Record 45 of Set 10 | chute-aux-outardes
# Processing Record 46 of Set 10 | sola
# Processing Record 47 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 10 | cervo
# Processing Record 49 of Set 10 | merrill
# Processing Record 50 of Set 10 | quezaltepeque
# Processing Record 1 of Set 11 | talcahuano
# Processing Record 2 of Set 11 | gat
# Processing Record 3 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 11 | senj
# Processing Record 5 of Set 11 | whitehorse
# Processing Record 6 of Set 11 | rio verde de mato grosso
# Processing Record 7 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 8 of Set 11 | puerto leguizamo
# Processing Record 9 of Set 11 | sorong
# Processing Record 10 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 11 | qibili
# City not found. Skipping...
# Processing Record 12 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 11 | alofi
# Processing Record 14 of Set 11 | ilebo
# Processing Record 15 of Set 11 | shamkhal
# Processing Record 16 of Set 11 | yarmouth
# Processing Record 17 of Set 11 | tiznit
# Processing Record 18 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 11 | kearney
# Processing Record 20 of Set 11 | thunder bay
# Processing Record 21 of Set 11 | sayat
# Processing Record 22 of Set 11 | concepcion
# Processing Record 23 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 24 of Set 11 | westport
# Processing Record 25 of Set 11 | shirokiy
# Processing Record 26 of Set 11 | chicama
# Processing Record 27 of Set 11 | port blair
# Processing Record 28 of Set 11 | saint-georges
# Processing Record 29 of Set 11 | teodoro sampaio
# Processing Record 30 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 31 of Set 11 | tura
# Processing Record 32 of Set 11 | kisanga
# Processing Record 33 of Set 11 | songadh
# Processing Record 34 of Set 11 | impfondo
# Processing Record 35 of Set 11 | bongouanou
# Processing Record 36 of Set 11 | niquelandia
# Processing Record 37 of Set 11 | mareeba
# Processing Record 38 of Set 11 | muroto
# Processing Record 39 of Set 11 | zhangye
# Processing Record 40 of Set 11 | noumea
# Processing Record 41 of Set 11 | vardo
# Processing Record 42 of Set 11 | paamiut
# Processing Record 43 of Set 11 | bonthe
# Processing Record 44 of Set 11 | sept-iles
# Processing Record 45 of Set 11 | kasempa
# Processing Record 46 of Set 11 | supaul
# Processing Record 47 of Set 11 | ketchikan
# Processing Record 48 of Set 11 | san luis
# Processing Record 49 of Set 11 | muhos
# Processing Record 50 of Set 11 | fengzhen
# Processing Record 1 of Set 12 | turayf
# Processing Record 2 of Set 12 | san buenaventura
# Processing Record 3 of Set 12 | krasnoselkup
# Processing Record 4 of Set 12 | lamar
# Processing Record 5 of Set 12 | malumfashi
# Processing Record 6 of Set 12 | sao joao da barra
# Processing Record 7 of Set 12 | doha
# Processing Record 8 of Set 12 | makakilo city
# Processing Record 9 of Set 12 | tual
# Processing Record 10 of Set 12 | cairns
# Processing Record 11 of Set 12 | misratah
# Processing Record 12 of Set 12 | luganville
# Processing Record 13 of Set 12 | komatipoort
# Processing Record 14 of Set 12 | kempsey
# Processing Record 15 of Set 12 | kulhudhuffushi
# Processing Record 16 of Set 12 | matamoros
# Processing Record 17 of Set 12 | waiouru
# Processing Record 18 of Set 12 | bougouni
# Processing Record 19 of Set 12 | zhuanghe
# Processing Record 20 of Set 12 | pyaozerskiy
# Processing Record 21 of Set 12 | banka
# Processing Record 22 of Set 12 | capitan bado
# Processing Record 23 of Set 12 | san nicolas
# Processing Record 24 of Set 12 | aliwal north
# Processing Record 25 of Set 12 | moerai
# Processing Record 26 of Set 12 | ruidoso
# Processing Record 27 of Set 12 | pemangkat
# Processing Record 28 of Set 12 | kharagpur
# Processing Record 29 of Set 12 | monrovia
# Processing Record 30 of Set 12 | huarmey
# Processing Record 31 of Set 12 | locri
# Processing Record 32 of Set 12 | asayita
# City not found. Skipping...
# Processing Record 33 of Set 12 | namie
# Processing Record 34 of Set 12 | tamandare
# Processing Record 35 of Set 12 | preobrazheniye
# Processing Record 36 of Set 12 | zhiryatino
# Processing Record 37 of Set 12 | masuguru
# Processing Record 38 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 39 of Set 12 | veraval
# Processing Record 40 of Set 12 | koboldo
# City not found. Skipping...
# Processing Record 41 of Set 12 | pangai
# Processing Record 42 of Set 12 | joacaba
# Processing Record 43 of Set 12 | arthur
# Processing Record 44 of Set 12 | hargeysa
# Processing Record 45 of Set 12 | tromso
# Processing Record 46 of Set 12 | voh
# Processing Record 47 of Set 12 | sorland
# Processing Record 48 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 12 | amberley
# Processing Record 50 of Set 12 | pavino
# Processing Record 1 of Set 13 | conceicao do araguaia
# Processing Record 2 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 3 of Set 13 | lata
# Processing Record 4 of Set 13 | byron bay
# Processing Record 5 of Set 13 | nortelandia
# Processing Record 6 of Set 13 | ixtapa
# Processing Record 7 of Set 13 | lompoc
# Processing Record 8 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 9 of Set 13 | carahue
# Processing Record 10 of Set 13 | baripada
# Processing Record 11 of Set 13 | voskresenskoye
# Processing Record 12 of Set 13 | gavrilov-yam
# Processing Record 13 of Set 13 | laguna
# Processing Record 14 of Set 13 | flinders
# Processing Record 15 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 13 | galle
# Processing Record 17 of Set 13 | oxford
# Processing Record 18 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 13 | penzance
# Processing Record 20 of Set 13 | antigonish
# Processing Record 21 of Set 13 | kirakira
# Processing Record 22 of Set 13 | atar
# Processing Record 23 of Set 13 | bud
# Processing Record 24 of Set 13 | mana
# Processing Record 25 of Set 13 | laguna de perlas
# Processing Record 26 of Set 13 | oreanda
# City not found. Skipping...
# Processing Record 27 of Set 13 | gwadar
# Processing Record 28 of Set 13 | alamogordo
# Processing Record 29 of Set 13 | kayanza
# Processing Record 30 of Set 13 | sao felix do xingu
# Processing Record 31 of Set 13 | koygorodok
# Processing Record 32 of Set 13 | macae
# Processing Record 33 of Set 13 | dongning
# Processing Record 34 of Set 13 | kyabram
# Processing Record 35 of Set 13 | chongwe
# Processing Record 36 of Set 13 | prince rupert
# Processing Record 37 of Set 13 | ornskoldsvik
# Processing Record 38 of Set 13 | atasu
# Processing Record 39 of Set 13 | baghdad
# Processing Record 40 of Set 13 | santa rosa
# Processing Record 41 of Set 13 | bull savanna
# Processing Record 42 of Set 13 | solenzo
# Processing Record 43 of Set 13 | gladstone
# Processing Record 44 of Set 13 | ust-koksa
# Processing Record 45 of Set 13 | tallahassee
# Processing Record 46 of Set 13 | kavieng
# Processing Record 47 of Set 13 | shelburne
# Processing Record 48 of Set 13 | muriti
# Processing Record 49 of Set 13 | ballybofey
# Processing Record 50 of Set 13 | altay
# Processing Record 1 of Set 14 | anadyr
# Processing Record 2 of Set 14 | eydhafushi
# Processing Record 3 of Set 14 | havelock
# Processing Record 4 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 14 | norilsk
# Processing Record 6 of Set 14 | vysotsk
# Processing Record 7 of Set 14 | zhigansk
# Processing Record 8 of Set 14 | sandi
# Processing Record 9 of Set 14 | elban
# Processing Record 10 of Set 14 | beaverlodge
# Processing Record 11 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 14 | belyy yar
# Processing Record 13 of Set 14 | san cosme y damian
# Processing Record 14 of Set 14 | haizhou
# Processing Record 15 of Set 14 | padang
# Processing Record 16 of Set 14 | bandipur
# Processing Record 17 of Set 14 | qaqortoq
# Processing Record 18 of Set 14 | borogontsy
# Processing Record 19 of Set 14 | udachnyy
# Processing Record 20 of Set 14 | coihaique
# Processing Record 21 of Set 14 | ewa beach
# Processing Record 22 of Set 14 | aswan
# Processing Record 23 of Set 14 | liter
# Processing Record 24 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 14 | samarai
# Processing Record 26 of Set 14 | ulladulla
# Processing Record 27 of Set 14 | pindiga
# Processing Record 28 of Set 14 | hatfield
# Processing Record 29 of Set 14 | rawson
# Processing Record 30 of Set 14 | huesca
# Processing Record 31 of Set 14 | manta
# Processing Record 32 of Set 14 | charlottetown
# Processing Record 33 of Set 14 | aracati
# Processing Record 34 of Set 14 | portland
# Processing Record 35 of Set 14 | mushie
# Processing Record 36 of Set 14 | sokoni
# Processing Record 37 of Set 14 | nassau
# Processing Record 38 of Set 14 | batken
# Processing Record 39 of Set 14 | puntarenas
# Processing Record 40 of Set 14 | cayenne
# Processing Record 41 of Set 14 | pingliang
# Processing Record 42 of Set 14 | harstad
# Processing Record 43 of Set 14 | faya
# Processing Record 44 of Set 14 | wakkanai
# Processing Record 45 of Set 14 | rio gallegos
# Processing Record 46 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 47 of Set 14 | terney
# Processing Record 48 of Set 14 | lubuk pakam
# Processing Record 49 of Set 14 | guapore
# Processing Record 50 of Set 14 | sayyan
# Processing Record 1 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 15 | coquimbo
# Processing Record 3 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 5 of Set 15 | fairbanks
# Processing Record 6 of Set 15 | tilichiki
# Processing Record 7 of Set 15 | terrace bay
# Processing Record 8 of Set 15 | saurimo
# Processing Record 9 of Set 15 | capreol
# Processing Record 10 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 15 | belmonte
# Processing Record 12 of Set 15 | tigil
# Processing Record 13 of Set 15 | male
# Processing Record 14 of Set 15 | ures
# Processing Record 15 of Set 15 | kalmar
# Processing Record 16 of Set 15 | ashqelon
# Processing Record 17 of Set 15 | koslan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Rikitea -23.12 -134.97     76.96        76          74
# 1       Port Alfred -33.59   26.89     71.01        82           0
# 2    Cabo San Lucas  22.89 -109.91     73.40        43          40
# 3          Thompson  55.74  -97.86     23.00        57          75
# 4     Saint Anthony  45.02  -93.22     42.01        44          40
# ..              ...    ...     ...       ...       ...         ...
# 654            Male   4.17   73.51     84.20        79          75
# 655            Ures  29.43 -110.40     75.00        37           0
# 656          Kalmar  56.66   16.36     37.00       100          82
# 657        Ashqelon  31.67   34.57     59.00        82           0
# 658          Koslan  63.46   48.90      8.24        95           0
#
#      Wind Speed Country Current Description  Rain Inches (last 3 hours)  \
# 0         20.18      PF       broken clouds                         0.0
# 1          5.99      ZA           clear sky                         0.0
# 2         11.41      MX    scattered clouds                         0.0
# 3          4.70      CA       broken clouds                         0.0
# 4          9.17      US    scattered clouds                         0.0
# ..          ...     ...                 ...                         ...
# 654        8.05      MV       broken clouds                         0.0
# 655        5.01      MX           clear sky                         0.0
# 656        5.82      SE       broken clouds                         0.0
# 657        3.36      IL           clear sky                         0.0
# 658        3.98      RU           clear sky                         0.0
#
#      Snow Inches (last 3 hours)                 Date
# 0                           0.0  2020-03-04 22:00:26
# 1                           0.0  2020-03-04 22:00:26
# 2                           0.0  2020-03-04 22:00:09
# 3                           0.0  2020-03-04 22:00:27
# 4                           0.0  2020-03-04 22:00:27
# ..                          ...                  ...
# 654                         0.0  2020-03-04 22:03:03
# 655                         0.0  2020-03-04 22:03:03
# 656                         0.0  2020-03-04 22:03:03
# 657                         0.0  2020-03-04 22:03:04
# 658                         0.0  2020-03-04 22:03:04
#
# [659 rows x 12 columns]

# %%
city_data_df.to_csv('WeatherPy_challenge.csv')
